# %%
from dotenv import load_dotenv
import pandas as pd
from datasets import load_dataset
import os
from tqdm.auto import tqdm
import pinecone

# %%
load_dotenv()
PINECONE_KEY = os.getenv("PINECONE_KEY")
hf_token = os.getenv("HF_TOKEN")

# %%
model_id = "sentence-transformers/all-MiniLM-L6-v2"
hf_token = hf_token

# %%
import requests

api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
headers = {"Authorization": f"Bearer {hf_token}"}

# %%
def query(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts, "options":{"wait_for_model":True}})
    return response.json()

# %%
sample_texts = [
    "This is the first sample text",
    "These texts are required to load the model without errors during the main embedding calculations"
]
sample_output = query(sample_texts)

# %%
sample_output
# Out:
# [[-0.02273164875805378,
#   0.0477682463824749,
#   -0.00668375426903367,
#   0.03634946048259735,
#   0.06079265847802162,
#   0.0396263562142849,
#   0.060343846678733826,
#   0.03269622102379799,
#   0.032260194420814514,
#   -0.017252592369914055,
#   0.054471466690301895,
#   0.009407194331288338,
#   -0.013869247399270535,
#   -0.050972700119018555,
#   0.009013917297124863,
#   0.04846423491835594,
#   0.06679240614175797,
#   -0.058826882392168045,
#   0.004202724434435368,
#   -8.080745465122163e-05,
#   0.048516009002923965,
#   0.08671743422746658,
#   0.06877390295267105,
#   0.015224380418658257,
#   0.019572166725993156,
#   0.05134625732898712,
#   -0.03643522784113884,
#   0.07847463339567184,
#   0.11318924278020859,
#   -0.04334423691034317,
#   -0.024414412677288055,
#   0.05804324150085449,
#   0.17109976708889008,
#   0.03223296254873276,
#   0.08333372324705124,
#   0.010822674259543419,
#   -0.019283119589090347,
#   0.03212469443678856,
#   0.027633683755993843,
#   0.09738506376743317,
#   0.012617363594472408,
#   -0.0943077951669693,
#   0.02132544107735157,
#   0.0007207534508779645,
#   0.027251599356532097,
#   -0.02734118513762951,
#   -0.046730104833841324,
#   0.01683931238949299,
#   0.011549930088222027,
#   0.057123877108097076,
#   -0.07954996824264526,
#   -0.0183277390897274,
#   -0.051022719591856,
#   -0.009912585839629173,
#   0.031835075467824936,
#   0.03649791702628136,
#   -0.0067660389468073845,
#   -0.01969456486403942,
#   0.0017658541910350323,
#   -0.015084516257047653,
#   -0.012539013288915157,
#   -0.0008503540302626789,
#   -0.04027238115668297,
#   0.05973038449883461,
#   0.09678533673286438,
#   -0.005763223860412836,
#   -0.006481846794486046,
#   -0.008225452154874802,
#   -0.047484491020441055,
#   0.013933103531599045,
#   -0.07514363527297974,
#   0.051260899752378464,
#   -0.029623808339238167,
#   0.07739624381065369,
#   -0.06518908590078354,
#   0.002888735616579652,
#   -0.07033300399780273,
#   -0.08682946860790253,
#   0.039144694805145264,
#   -0.04928360506892204,
#   -0.02746398188173771,
#   -0.04685940966010094,
#   0.00517315324395895,
#   0.08600147068500519,
#   -0.06889117509126663,
#   0.06357870995998383,
#   -0.0154976025223732,
#   -0.00368236075155437,
#   -0.0024476998951286077,
#   -0.015154603868722916,
#   -0.005802918691188097,
#   0.01032243762165308,
#   0.02095259353518486,
#   0.040503211319446564,
#   -0.1028691902756691,
#   0.030957253649830818,
#   0.013030987232923508,
#   0.02550542913377285,
#   -0.03104136884212494,
#   -0.03519907221198082,
#   0.0458260178565979,
#   0.0844108983874321,
#   0.028323816135525703,
#   -0.00040656491182744503,
#   0.02529599703848362,
#   0.004796002060174942,
#   -0.05479337275028229,
#   0.048309437930583954,
#   0.0011772714788094163,
#   -0.011217009276151657,
#   0.006611011456698179,
#   0.044278793036937714,
#   0.0207123551517725,
#   -0.03018035925924778,
#   -0.04029335826635361,
#   0.13185489177703857,
#   0.10081993043422699,
#   -0.01653658226132393,
#   -0.015018824487924576,
#   0.046352237462997437,
#   0.04920676723122597,
#   0.01747765578329563,
#   -0.028301872313022614,
#   -0.011767244897782803,
#   0.11994285136461258,
#   0.037745047360658646,
#   -0.11101794987916946,
#   -0.0012367833405733109,
#   0.005418246146291494,
#   -0.00960229616612196,
#   -0.010821860283613205,
#   -0.01548266876488924,
#   -0.1162494644522667,
#   0.06299135833978653,
#   -0.0367683470249176,
#   -0.02472175471484661,
#   0.051727842539548874,
#   -0.02549564652144909,
#   -0.030942514538764954,
#   -0.06419719010591507,
#   0.041992101818323135,
#   0.01926366798579693,
#   0.01903126947581768,
#   -0.05102464184165001]]

# %%
EMBEDDING_LENGTH = len(sample_output[0])

# %%
import zipfile
zipref = zipfile.ZipFile('data_zip.zip')
zipref.extractall()
zipref.close()

# %%
data_files = "arxiv-metadata-oai-snapshot.json"
arxiv_dataset = load_dataset("json", data_files=data_files, split="train[:15000]")
arxiv_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['id', 'submitter', 'authors', 'title', 'comments', 'journal-ref', 'doi', 'report-no', 'categories', 'license', 'abstract', 'versions', 'update_date', 'authors_parsed'],
#     num_rows: 15000
# })

# %%
print("Length of Abstract:", len(arxiv_dataset[0]['abstract']))
# Out:
# Length of Abstract: 983

# %%
columns = arxiv_dataset.column_names
columns_to_keep = ["title", "doi", "abstract", 'id']
columns_to_remove = set(columns_to_keep).symmetric_difference(columns)
arxiv_dataset = arxiv_dataset.remove_columns(columns_to_remove)
arxiv_dataset
# Out:
# Dataset({
#     features: ['id', 'title', 'doi', 'abstract'],
#     num_rows: 15000
# })

# %%
from pinecone import Pinecone, ServerlessSpec
index_name = 'semantic-search'

# initialize connection to pinecone (get API key at app.pinecone.io)
pc = Pinecone(
    api_key=PINECONE_KEY, # find next to api key in   console
)
# check if index already exists (only create index if not)
if index_name not in pc.list_indexes().names():
    pc.create_index(index_name, dimension=EMBEDDING_LENGTH, spec = ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) )
# connect to index
index = pc.Index(index_name)

# %%
count = 0  # we'll use the count to create unique IDs
batch_size = 32  # process everything in batches of 32

for i in tqdm(range(0, len(arxiv_dataset['abstract']), batch_size)):
    # set end position of batch
    i_end = min(i+batch_size, len(arxiv_dataset['abstract']))
    # get batch of lines and IDs
    abstracts_batch = arxiv_dataset['abstract'][i: i+batch_size]
    titles_batch = arxiv_dataset['title'][i: i+batch_size]
    ids_batch = arxiv_dataset['id'][i: i+batch_size]

    # ids_batch = [str(n) for n in range(i, i_end)]
    # create embeddings
    embeds = query(abstracts_batch)
    # prep metadata and upsert batch
    meta = [{'abstract': abstract, 'title': title} for abstract, title in zip(abstracts_batch, titles_batch)]
#   -0.030744237825274467,
#   0.006509822327643633,
#   -0.07728234678506851,
#   0.031026029959321022,
#   -0.007924810983240604,
#   0.0037864840123802423,
#   -0.10996954143047333,
#   0.04917502403259277,
#   -0.0493864044547081,
#   0.0740264505147934,
#   -0.024142343550920486,
#   -0.006813189946115017,
#   0.06942223757505417,
#   -0.10071404278278351,
#   0.015916287899017334,
#   -0.06014334410429001,
#   -0.06723998486995697,
#   -0.0636807531118393]]

# %%
from pinecone import Pinecone
pc = Pinecone(
    api_key=PINECONE_KEY,
)
index_name = 'semantic-search'
index = pc.Index(index_name)

# %%
res = index.query(vector = xq, top_k=5, include_metadata=True)
res
# Out:
# {'matches': [{'id': '0705.4229',
#               'metadata': {'abstract': '  Precursor MgB2 thin films were '
#                                        'prepared on sapphire substrates by '
#                                        'magnetron\n'
#                                        'sputtering. Influence of ex-situ '
#                                        'annealing process on superconducting '
#                                        'MgB2 thin\n'
#                                        'films roughness is discussed. '
#                                        'Optimized annealing process of MgB '
#                                        'precursor thin\n'
#                                        'films in vacuum results in smooth '
#                                        'superconducting MgB2 thin films with\n'
#                                        'roughness below 10 nm, critical '
#                                        'temperature Tcon = 31 K and transition '
#                                        'width\n'
#                                        'DTc less than 1 K. Nano-bridges based '
#                                        'on the superconducting MgB2 thin '
#                                        'films\n'
#                                        'using optical and Focused Ion Beam '
#                                        'lithography were prepared. Critical '
#                                        'current\n'
#                                        'density jc (4.2 K) measured on 50 nm '
#                                        'wide strip was 7.3x106 A/cm2 and no\n'
#                                        'significant loss of superconducting '
#                                        'properties was detected. Resistance '
#                                        'vs.\n'
#                                        'temperature and critical current vs. '
#                                        'temperature characteristics were '
#                                        'measured\n'
#                                        'on these structures using standard DC '
#                                        'four probe measurements.\n',
#                            'title': 'Superconducting MgB2 thin films '
#                                     'nano-bridges for cryo-electronic\n'
#                                     '  application'},
#               'score': 0.534846,
#               'values': []},
#              {'id': '0704.0696',
#               'metadata': {'abstract': '  Results of the first-principles '
#                                        'calculations are presented for the '
#                                        'group-VB\n'
#                                        'metals V, Nb and Ta up to couple of '
#                                        'megabar pressure. An unique '
#                                        'structural\n'
#                                        'phase transition sequence BCC-->(at 60 '
#                                        'GPa) rhombohedral (angle=110.5\n'
#                                        'degree)-->(at ~ 160 '
#                                        'GPa)rhombohedral(angle=108.5 '
#                                        'degree)--> (at ~ 430 GPa) BCC\n'
#                                        'is predicted in V. We also find that '
#                                        'BCC-V becomes mechanically and\n'
#                                        'vibrationally unstable at around 112 '
#                                        'GPa pressure. Similar transitions are\n'
#                                        'absent in Nb and Ta.\n',
#                            'title': 'Phonon instability and structural phase '
#                                     'transition in Vanadium under\n'
#                                     '  high pressure'},
#               'score': 0.515555859,
#               'values': []},
#              {'id': '0706.3591',
#               'metadata': {'abstract': '  We report magnetoresistance (MR) '
#                                        'measurements on MgB2 and the '
#                                        'corresponding\n'
#                                        'full account from ab-initio '
#                                        'calculations; we suggest that this '
#                                        'combination can\n'
#                                        'be a useful tool to probe electron- '
#                                        'phonon coupling. We obtain good\n'
#                                        'quantitative agreement between high '
#                                        'field measurements on neutron '
#                                        'irradiated\n'
#                                        'epitaxial thin films and calculations '
#                                        'within Bloch-Boltzmann transport '
#                                        'theory\n'
#                                        'over a wide range of magnetic fields '
#                                        '(0-28 T) and temperatures (40-300 K), '
#                                        'and\n'
#                                        'as a function of the field '
#                                        'orientation. The crossovers between '
#                                        'in-plane and\n'
#                                        'out-of-plane MR, experimentally '
#                                        'observed as a function of either '
#                                        'disorder or\n'
#                                        'temperature are well reproduced '
#                                        'indicating that disorder and '
#                                        'interaction with\n'
#                                        'phonons strongly affect the scattering '
#                                        'rate of s-carriers.\n',
#                            'title': 'Probing the electron-phonon coupling in '
#                                     'MgB2 through magnetoresistance\n'
#                                     '  measurements in neutron irradiated thin '
#                                     'films'},
#               'score': 0.482971489,
#               'values': []},
#              {'id': '0704.0126',
#               'metadata': {'abstract': '  The current-voltage (I-V) '
#                                        'characteristics of various MgB2 films '
#                                        'have been\n'
#                                        'studied at different magnetic fields '
#                                        'parallel to c-axis. At fields \\mu0H\n'
#                                        'between 0 and 5T, vortex liquid-glass '
#                                        'transitions were found in the I-V\n'
#                                        'isotherms. Consistently, the I-V '
#                                        'curves measured at different '
#                                        'temperatures show\n'
#                                        'a scaling behavior in the framework of '
#                                        'quasi-two-dimension (quasi-2D) vortex\n'
#                                        'glass theory. However, at \\mu0 H >= '
#                                        '5T, a finite dissipation was observed '
#                                        'down\n'
#                                        'to the lowest temperature here, '
#                                        'T=1.7K, and the I-V isotherms did not '
#                                        'scale in\n'
#                                        'terms of any known scaling law, of any '
#                                        'dimensionality. We suggest that this '
#                                        'may\n'
#                                        'be caused by a mixture of \\sigma band '
#                                        'vortices and \\pi band '
#                                        'quasiparticles.\n'
#                                        'Interestingly, the I-V curves at zero '
#                                        'magnetic field can still be scaled\n'
#                                        'according to the quasi-2D vortex glass '
#                                        'formalism, indicating an equivalent\n'
#                                        'effect of self-field due to persistent '
#                                        'current and applied magnetic field.\n',
#                            'title': 'I-V characteristics of the vortex state '
#                                     'in MgB2 thin films'},
#               'score': 0.480564713,
#               'values': []},
#              {'id': '0706.2177',
#               'metadata': {'abstract': '  Specific heat, electrical '
#                                        'resistivity, and magnetic '
#                                        'susceptibility\n'
#                                        'measurements on a high quality sample '
#                                        'of Mg10Ir19B16 provide a '
#                                        'self-consistent\n'
#                                        'determination of its superconducting '
#                                        'properties. They indicate that '
#                                        'Mg10Ir19B16\n'
#                                        'is a type-II superconductor (Tc=4.45K, '
#                                        'k(0)=20), with an electron-phonon\n'
#                                        'coupling constant l_ep=0.66. An '
#                                        'analysis of the T-dependent specific '
#                                        'heat shows\n'
#                                        'that superconducting properties are '
#                                        'dominated by an s-wave gap (D=0.7 '
#                                        'meV).\n'
#                                        'Point contact tunneling data provide '
#                                        'evidence for multiple superconducting\n'
#                                        'gaps, as expected from strong '
#                                        'asymmetric spin-orbit coupling.\n',
#                            'title': 'Physical properties of the '
#                                     'noncentrosymmetric superconductor\n'
#                                     '  Mg_10Ir_19B_16'},
#               'score': 0.469938695,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %%
for key in res['matches'][0].to_dict():
    if key != 'values':
        print(key)
# Out:
# id
# score
# metadata
